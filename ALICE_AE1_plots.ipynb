# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Anomalies_1 = np.loadtxt('Anomalies_d1')
Non_anomalies_1 = np.loadtxt('Non_anomalies_d1')    
Predictions = np.loadtxt('Predictions_d1')
dataset = np.loadtxt('dataset_d1')
History_train = np.loadtxt('History_train_d1')
History_validate = np.loadtxt('History_validate_d1')

# %%
signal_length = 160

plt.figure(figsize=(20,4))
plt.plot(Anomalies_1, 'r')
plt.plot(Non_anomalies_1, 'b')
plt.plot(dataset, 'k')
plt.ylim([0,1])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
plt.figure(figsize=(20,4))
plt.plot(dataset, 'k')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
plt.figure(figsize=(20,7))
plt.plot(History_train, 'b', label='train')
plt.plot(History_validate, 'r', label='test')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='best')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
# %matplotlib notebook

# %%
from matplotlib import animation, rc
from IPython.display import HTML
import time

# %%
plt.figure(figsize=(10,5))
fig = plt.gcf()
fig.show()
fig.canvas.draw()
rate = 3

for i in range(len(dataset)):
    plt.plot(dataset[rate*i:rate*i+signal_length-50], 'k')
    plt.plot(Anomalies_1[rate*i:rate*i+signal_length], 'r')
    plt.plot(Non_anomalies_1[rate*i:rate*i+signal_length], 'b')
    plt.ylim([0,1])
    plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
    fig.canvas.draw()
    plt.clf()
# Out:
# <img src="data:image/png;base64,..." width="1000">
